# %% [markdown]
# # Doc Intelligence — one-click run
#
# This notebook clones the repository, installs it, and runs the demo end-to-end. **Runtime → Run all**.
#
# Runs fully on the free Colab CPU runtime — no API keys, no data downloads (all demo data is generated in code).

# %% [markdown]
# ### 1. Clone the repository

# %%
import os
if not os.path.isdir('/content/doc-intelligence'):
    # !git clone -q https://github.com/akshay-birla-03/doc-intelligence.git /content/doc-intelligence
# %cd /content/doc-intelligence

# %% [markdown]
# ### 2. Install

# %%
# !pip install -q -e .

# %% [markdown]
# ### 3. Run the demo

# %%
# !printf 'ACME Corporation\nINVOICE\nInvoice Number: INV-2045\nDate: 03/14/2026\nBill To: Jane Smith, jane@acme.com, +1 415-555-0132\nSubtotal: $1,200.00\nTax: $216.00\nTotal: $1,416.00\n' > sample.txt && docintel sample.txt
